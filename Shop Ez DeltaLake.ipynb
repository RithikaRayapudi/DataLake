# %%
# Basic setup – importing required Delta + Spark functions.
# Also creates the storage path inside a Databricks Volume 
from delta.tables import DeltaTable
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, DoubleType
import datetime, traceback

path = "dbfs:/Volumes/rithika/default/data/shopez_new/orders"
dbutils.fs.mkdirs(path)
print("Using path:", path)
# Out:
# Using path: dbfs:/Volumes/rithika/default/data/shopez_new/orders

# %%
# Task 1: Ingest sample order data into a Spark DataFrame.
# We simulate incoming JSON/CSV by creating Python dictionaries and applying a schema.
# This represents daily data ingestion step.

sample_data_v1 = [
    {"order_id": "o1001", "order_timestamp": "2025-11-28 10:05:00", "customer_id": "c100", "country": "US", "amount": 120.50, "currency": "USD", "status": "CREATED"},
    {"order_id": "o1002", "order_timestamp": "2025-11-28 11:10:00", "customer_id": "c101", "country": "IN", "amount": 2500.00, "currency": "INR", "status": "PAID"},
    {"order_id": "o1003", "order_timestamp": "2025-11-29 09:00:00", "customer_id": "c102", "country": "US", "amount": 15.00, "currency": "USD", "status": "PAID"},
    {"order_id": "o1004", "order_timestamp": "2025-11-29 12:30:00", "customer_id": "c103", "country": "GB", "amount": 75.00, "currency": "GBP", "status": "CREATED"},
]

schema_v1 = StructType([
    StructField("order_id", StringType(), False),
    StructField("order_timestamp", StringType(), False),
    StructField("customer_id", StringType(), False),
    StructField("country", StringType(), False),
    StructField("amount", DoubleType(), False),
    StructField("currency", StringType(), False),
    StructField("status", StringType(), False),
])

df_v1 = spark.createDataFrame(sample_data_v1, schema=schema_v1)

# Task 2: Add derived column 'order_date' for partitioning.
# Extracting only the DATE from a TIMESTAMP reduces the number of partitions and speeds queries.
df_v1 = df_v1.withColumn("order_timestamp", col("order_timestamp").cast(TimestampType()))
df_v1 = df_v1.withColumn("order_date", to_date(col("order_timestamp")))

display(df_v1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>country</th><th>amount</th><th>currency</th><th>status</th><th>order_date</th></tr></thead><tbody><tr><td>o1001</td><td>2025-11-28T10:05:00Z</td><td>c100</td><td>US</td><td>120.5</td><td>USD</td><td>CREATED</td><td>2025-11-28</td></tr><tr><td>o1002</td><td>2025-11-28T11:10:00Z</td><td>c101</td><td>IN</td><td>2500.0</td><td>INR</td><td>PAID</td><td>2025-11-28</td></tr><tr><td>o1003</td><td>2025-11-29T09:00:00Z</td><td>c102</td><td>US</td><td>15.0</td><td>USD</td><td>PAID</td><td>2025-11-29</td></tr><tr><td>o1004</td><td>2025-11-29T12:30:00Z</td><td>c103</td><td>GB</td><td>75.0</td><td>GBP</td><td>CREATED</td><td>2025-11-29</td></tr></tbody></table></div>

# %%
# Task 3: Write the DataFrame as a Delta table partitioned by country + order_date.
# Partitioning helps reduce file scanning and improves performance for country/date filters.

df_v1.write.format("delta") \
    .mode("overwrite") \
    .partitionBy("country", "order_date") \
    .save(path)

print("Delta table written successfully.")
# Out:
# Delta table written successfully.

# %%
registered_in_hive = False

try:
    spark.sql("USE CATALOG hive_metastore")
    spark.sql("CREATE DATABASE IF NOT EXISTS default")
    spark.sql(f"""
        CREATE TABLE IF NOT EXISTS default.shopez_orders
        USING DELTA
        LOCATION '{path}'
    """)
    registered_in_hive = True
    print("Table registered in hive_metastore.")
except:
    print("Registration failed, falling back to TEMP VIEW.")

if not registered_in_hive:
    spark.read.format("delta").load(path).createOrReplaceTempView("shopez_orders_v")
    print("Created TEMP VIEW: shopez_orders_v")
# Out:
# Table registered in hive_metastore.

# %%
# Task 4: Verify the partition structure inside the storage path.
# This confirms that country and order_date folders were created properly.

print("Parent folder:")
display(dbutils.fs.ls("dbfs:/Volumes/rithika/default/data/shopez_new"))

print("Delta table contents:")
display(dbutils.fs.ls(path))

print("Partition directories:")
for p in dbutils.fs.ls(path):
    if p.isDir():
        print("-", p.path)
# Out:
# Parent folder:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/</td><td>orders/</td><td>0</td><td>1764599065000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/</td><td>orders_smallfiles_demo/</td><td>0</td><td>1764599837000</td></tr></tbody></table></div>
# Delta table contents:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1764599288000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=GB/</td><td>country=GB/</td><td>0</td><td>1764599290000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=IN/</td><td>country=IN/</td><td>0</td><td>1764599290000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=US/</td><td>country=US/</td><td>0</td><td>1764599289000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_23f98b53-b8f9-486d-9f5b-7b49b5be48d7.bin</td><td>deletion_vector_23f98b53-b8f9-486d-9f5b-7b49b5be48d7.bin</td><td>43</td><td>1764599305000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_3fcc21d0-1811-4c21-9c6e-ce37fa0a6508.bin</td><td>deletion_vector_3fcc21d0-1811-4c21-9c6e-ce37fa0a6508.bin</td><td>43</td><td>1764601015000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_5eff52c8-2f2c-4754-bdb4-17f1ae6b1687.bin</td><td>deletion_vector_5eff52c8-2f2c-4754-bdb4-17f1ae6b1687.bin</td><td>43</td><td>1764599873000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_7d25368c-e50e-443f-98f7-7c565cebddca.bin</td><td>deletion_vector_7d25368c-e50e-443f-98f7-7c565cebddca.bin</td><td>43</td><td>1764599299000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_8674d8bb-b3a6-4fb1-8985-bebf4739881d.bin</td><td>deletion_vector_8674d8bb-b3a6-4fb1-8985-bebf4739881d.bin</td><td>43</td><td>1764599758000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_9d3d622f-0d51-4043-8cb8-ddeae2fd650a.bin</td><td>deletion_vector_9d3d622f-0d51-4043-8cb8-ddeae2fd650a.bin</td><td>43</td><td>1764599752000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_c5050c5d-d774-4d66-b608-a07e2b565511.bin</td><td>deletion_vector_c5050c5d-d774-4d66-b608-a07e2b565511.bin</td><td>43</td><td>1764599878000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_c9b00c3d-342a-493c-a730-e5d6f2eaab55.bin</td><td>deletion_vector_c9b00c3d-342a-493c-a730-e5d6f2eaab55.bin</td><td>43</td><td>1764601590000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders/deletion_vector_e5995003-233a-452a-be6f-8dc94c9622ef.bin</td><td>deletion_vector_e5995003-233a-452a-be6f-8dc94c9622ef.bin</td><td>43</td><td>1764601019000</td></tr></tbody></table></div>
# Partition directories:
# - dbfs:/Volumes/rithika/default/data/shopez_new/orders/_delta_log/
# - dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=GB/
# - dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=IN/
# - dbfs:/Volumes/rithika/default/data/shopez_new/orders/country=US/

# %%
# Task 5: Partition pruning demo.
# When filtering by partition columns, Spark will skip scanning unrelated folders.

q = spark.read.format("delta").load(path) \
    .filter((col("country") == "US") & (col("order_date") == "2025-11-28"))

display(q)

print("Explain Plan (to verify partition pruning):")
q.explain(True)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>country</th><th>amount</th><th>currency</th><th>status</th><th>order_date</th><th>payment_method</th><th>coupon_code</th></tr></thead><tbody><tr><td>o1001</td><td>2025-11-28T10:05:00Z</td><td>c100</td><td>US</td><td>120.5</td><td>USD</td><td>CREATED</td><td>2025-11-28</td><td>null</td><td>null</td></tr></tbody></table></div>
# Explain Plan (to verify partition pruning):
# == Parsed Logical Plan ==
# 'Filter 'and('`=`('country, US), '`=`('order_date, 2025-11-28))
# +- Relation [order_id#12379,order_timestamp#12380,customer_id#12381,country#12382,amount#12383,currency#12384,status#12385,order_date#12386,payment_method#12387,coupon_code#12388] parquet
#
# == Analyzed Logical Plan ==
# order_id: string, order_timestamp: timestamp, customer_id: string, country: string, amount: double, currency: string, status: string, order_date: date, payment_method: string, coupon_code: string
# Filter ((country#12382 = US) AND (order_date#12386 = cast(2025-11-28 as date)))
# +- Relation [order_id#12379,order_timestamp#12380,customer_id#12381,country#12382,amount#12383,currency#12384,status#12385,order_date#12386,payment_method#12387,coupon_code#12388] parquet
#
# == Optimized Logical Plan ==
# Filter (((isnotnull(order_date#12386) AND (order_date#12386 = 2025-11-28)) AND isnotnull(country#12382)) AND (country#12382 = US))
# +- Relation [order_id#12379,order_timestamp#12380,customer_id#12381,country#12382,amount#12383,currency#12384,status#12385,order_date#12386,payment_method#12387,coupon_code#12388] parquet
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonProject [order_id#12379, order_timestamp#12380, customer_id#12381, country#12382, amount#12383, currency#12384, status#12385, order_date#12386, payment_method#12387, coupon_code#12388]
#       +- PhotonScan parquet [order_id#12379,order_timestamp#12380,customer_id#12381,amount#12383,currency#12384,status#12385,payment_method#12387,coupon_code#12388,country#12382,order_date#12386] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[dbfs:/Volumes/rithika/default/data/shopez_new/orders], OptionalDataFilters: [], PartitionFilters: [isnotnull(order_date#12386), (order_date#12386 = 2025-11-28), isnotnull(country#12382), (country..., ReadSchema: struct<order_id:string,order_timestamp:timestamp,customer_id:string,amount:double,currency:string..., RequiredDataFilters: []
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# Task 6: Time Travel demo.
# Delta Lake keeps versions of data, allowing rollback or audit via version numbers.

dt = DeltaTable.forPath(spark, path)

print("History before update:")
dt.history().show(truncate=False)

dt.update("order_id = 'o1001'", {"status": "'PAID'"})  # creates new version

print("History after update:")
dt.history().show(truncate=False)

print("Reading version 0 (before update):")
display(spark.read.format("delta").option("versionAsOf", 0).load(path))
# Out:
# History before update:
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# |version|timestamp          |userId         |userName                 |operation|operationParameters                                                               |job |notebook          |clusterId           |readVersion|isolationLevel   |isBlindAppend|operationMetrics                                                                                                                                                                                                                                                                                                              |userMetadata|engineInfo                                |
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# |24     |2025-12-01 15:23:47|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|23         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 4, numRemovedBytes -> 6553, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                    |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |23     |2025-12-01 15:08:11|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|22         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11006, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |22     |2025-12-01 15:06:44|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|21         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |21     |2025-12-01 15:06:31|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#10463 = o1001)"]}                                       |NULL|{3608994033321026}|1122-050139-4r473gd7|20         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 2157, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1289, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 865}|NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |20     |2025-12-01 15:05:49|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|19         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |19     |2025-12-01 14:57:01|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#9310 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|18         |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 215, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 215, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |18     |2025-12-01 14:57:00|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#9310 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|17         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1139, numDeletionVectorsUpdated -> 0, scanTimeMs -> 537, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 595} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |17     |2025-12-01 14:56:58|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|16         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |16     |2025-12-01 14:56:56|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#8272 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|15         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1597, numDeletionVectorsUpdated -> 0, scanTimeMs -> 799, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 796} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |15     |2025-12-01 14:56:50|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|14         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |14     |2025-12-01 14:38:00|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#7057 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|13         |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 316, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 315, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |13     |2025-12-01 14:37:59|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#7057 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|12         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1660, numDeletionVectorsUpdated -> 0, scanTimeMs -> 829, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 818} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |12     |2025-12-01 14:37:56|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|11         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |11     |2025-12-01 14:37:54|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#6019 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|10         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1652, numDeletionVectorsUpdated -> 0, scanTimeMs -> 884, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 764} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |10     |2025-12-01 14:37:48|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|9          |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |9      |2025-12-01 14:36:00|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#4378 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|8          |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 280, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 279, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |8      |2025-12-01 14:35:59|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#4378 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|7          |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1620, numDeletionVectorsUpdated -> 0, scanTimeMs -> 892, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 715} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |7      |2025-12-01 14:35:56|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|6          |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |6      |2025-12-01 14:35:53|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#3340 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|5          |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1842, numDeletionVectorsUpdated -> 0, scanTimeMs -> 985, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 856} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |5      |2025-12-01 14:35:44|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|4          |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11063, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# only showing top 20 rows
# History after update:
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# |version|timestamp          |userId         |userName                 |operation|operationParameters                                                               |job |notebook          |clusterId           |readVersion|isolationLevel   |isBlindAppend|operationMetrics                                                                                                                                                                                                                                                                                                              |userMetadata|engineInfo                                |
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# |25     |2025-12-01 15:25:23|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#12469 = o1001)"]}                                       |NULL|{3608994033321026}|1122-050139-4r473gd7|24         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1665, numDeletionVectorsUpdated -> 0, scanTimeMs -> 963, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 701} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |24     |2025-12-01 15:23:47|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|23         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 4, numRemovedBytes -> 6553, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                    |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |23     |2025-12-01 15:08:11|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|22         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11006, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |22     |2025-12-01 15:06:44|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|21         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |21     |2025-12-01 15:06:31|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#10463 = o1001)"]}                                       |NULL|{3608994033321026}|1122-050139-4r473gd7|20         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 2157, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1289, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 865}|NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |20     |2025-12-01 15:05:49|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|19         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |19     |2025-12-01 14:57:01|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#9310 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|18         |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 215, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 215, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |18     |2025-12-01 14:57:00|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#9310 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|17         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1139, numDeletionVectorsUpdated -> 0, scanTimeMs -> 537, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 595} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |17     |2025-12-01 14:56:58|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|16         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |16     |2025-12-01 14:56:56|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#8272 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|15         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1597, numDeletionVectorsUpdated -> 0, scanTimeMs -> 799, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 796} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |15     |2025-12-01 14:56:50|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|14         |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |14     |2025-12-01 14:38:00|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#7057 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|13         |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 316, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 315, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |13     |2025-12-01 14:37:59|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#7057 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|12         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1660, numDeletionVectorsUpdated -> 0, scanTimeMs -> 829, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 818} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |12     |2025-12-01 14:37:56|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|11         |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |11     |2025-12-01 14:37:54|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#6019 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|10         |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1652, numDeletionVectorsUpdated -> 0, scanTimeMs -> 884, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 764} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |10     |2025-12-01 14:37:48|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Overwrite, statsOnLoad -> false, partitionBy -> ["country","order_date"]}|NULL|{3608994033321026}|1122-050139-4r473gd7|9          |WriteSerializable|false        |{numFiles -> 4, numRemovedFiles -> 6, numRemovedBytes -> 11412, numDeletionVectorsRemoved -> 0, numOutputRows -> 4, numOutputBytes -> 6553}                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |9      |2025-12-01 14:36:00|143678679799767|rithikarayapudi@gmail.com|DELETE   |{predicate -> ["(amount#4378 < 10.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|8          |WriteSerializable|false        |{numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 280, numDeletionVectorsUpdated -> 0, numAddedFiles -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numDeletedRows -> 0, scanTimeMs -> 279, numAddedBytes -> 0, rewriteTimeMs -> 0}          |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |8      |2025-12-01 14:35:59|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(amount#4378 < 20.0)"]}                                           |NULL|{3608994033321026}|1122-050139-4r473gd7|7          |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1630, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1620, numDeletionVectorsUpdated -> 0, scanTimeMs -> 892, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2036, rewriteTimeMs -> 715} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |7      |2025-12-01 14:35:56|143678679799767|rithikarayapudi@gmail.com|WRITE    |{mode -> Append, statsOnLoad -> false, partitionBy -> ["country","order_date"]}   |NULL|{3608994033321026}|1122-050139-4r473gd7|6          |WriteSerializable|true         |{numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 4091}                                                                                                                                                                                                                                                                   |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# |6      |2025-12-01 14:35:53|143678679799767|rithikarayapudi@gmail.com|UPDATE   |{predicate -> ["(order_id#3340 = o1001)"]}                                        |NULL|{3608994033321026}|1122-050139-4r473gd7|5          |WriteSerializable|false        |{numRemovedFiles -> 1, numRemovedBytes -> 1646, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, executionTimeMs -> 1842, numDeletionVectorsUpdated -> 0, scanTimeMs -> 985, numAddedFiles -> 1, numUpdatedRows -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, numAddedBytes -> 2008, rewriteTimeMs -> 856} |NULL        |Databricks-Runtime/17.3.x-photon-scala2.13|
# +-------+-------------------+---------------+-------------------------+---------+----------------------------------------------------------------------------------+----+------------------+--------------------+-----------+-----------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+------------------------------------------+
# only showing top 20 rows
# Reading version 0 (before update):
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>country</th><th>amount</th><th>currency</th><th>status</th><th>order_date</th></tr></thead><tbody><tr><td>o1001</td><td>2025-11-28T10:05:00Z</td><td>c100</td><td>US</td><td>120.5</td><td>USD</td><td>CREATED</td><td>2025-11-28</td></tr><tr><td>o1004</td><td>2025-11-29T12:30:00Z</td><td>c103</td><td>GB</td><td>75.0</td><td>GBP</td><td>CREATED</td><td>2025-11-29</td></tr><tr><td>o1002</td><td>2025-11-28T11:10:00Z</td><td>c101</td><td>IN</td><td>2500.0</td><td>INR</td><td>PAID</td><td>2025-11-28</td></tr><tr><td>o1003</td><td>2025-11-29T09:00:00Z</td><td>c102</td><td>US</td><td>15.0</td><td>USD</td><td>PAID</td><td>2025-11-29</td></tr></tbody></table></div>

# %%
# Task 7: Schema evolution.
# New columns (payment_method, coupon_code) are added in new incoming data.
# mergeSchema=true allows the Delta table to automatically update column definitions.

sample_data_v2 = [
    {"order_id": "o1005", "order_timestamp": "2025-11-30 14:00:00", "customer_id": "c104", "country": "IN",
     "amount": 499.0, "currency": "INR", "status": "PAID", "payment_method": "UPI", "coupon_code": None},
    {"order_id": "o1006", "order_timestamp": "2025-11-30 15:30:00", "customer_id": "c105", "country": "US",
     "amount": 199.99, "currency": "USD", "status": "CREATED", "payment_method": "CARD", "coupon_code": "WELCOME10"},
]

schema_v2 = StructType(schema_v1.fields + [
    StructField("payment_method", StringType(), True),
    StructField("coupon_code", StringType(), True),
])

df_v2 = spark.createDataFrame(sample_data_v2, schema=schema_v2)
df_v2 = df_v2.withColumn("order_timestamp", col("order_timestamp").cast(TimestampType()))
df_v2 = df_v2.withColumn("order_date", to_date(col("order_timestamp")))

df_v2.write.format("delta") \
    .mode("append") \
    .option("mergeSchema", "true") \
    .partitionBy("country", "order_date") \
    .save(path)

display(spark.read.format("delta").load(path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>country</th><th>amount</th><th>currency</th><th>status</th><th>order_date</th><th>payment_method</th><th>coupon_code</th></tr></thead><tbody><tr><td>o1006</td><td>2025-11-30T15:30:00Z</td><td>c105</td><td>US</td><td>199.99</td><td>USD</td><td>CREATED</td><td>2025-11-30</td><td>CARD</td><td>WELCOME10</td></tr><tr><td>o1001</td><td>2025-11-28T10:05:00Z</td><td>c100</td><td>US</td><td>120.5</td><td>USD</td><td>PAID</td><td>2025-11-28</td><td>null</td><td>null</td></tr><tr><td>o1005</td><td>2025-11-30T14:00:00Z</td><td>c104</td><td>IN</td><td>499.0</td><td>INR</td><td>PAID</td><td>2025-11-30</td><td>UPI</td><td>null</td></tr><tr><td>o1004</td><td>2025-11-29T12:30:00Z</td><td>c103</td><td>GB</td><td>75.0</td><td>GBP</td><td>CREATED</td><td>2025-11-29</td><td>null</td><td>null</td></tr><tr><td>o1002</td><td>2025-11-28T11:10:00Z</td><td>c101</td><td>IN</td><td>2500.0</td><td>INR</td><td>PAID</td><td>2025-11-28</td><td>null</td><td>null</td></tr><tr><td>o1003</td><td>2025-11-29T09:00:00Z</td><td>c102</td><td>US</td><td>15.0</td><td>USD</td><td>PAID</td><td>2025-11-29</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# Task 8: Updates & Deletes.
# Demonstrates how Delta supports ACID transactions for modifying existing data safely.

dt = DeltaTable.forPath(spark, path)

dt.update("amount < 20", {"status": "'CANCELLED'"})  # update rule
dt.delete("amount < 10")  # delete rule

display(spark.read.format("delta").load(path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_timestamp</th><th>customer_id</th><th>country</th><th>amount</th><th>currency</th><th>status</th><th>order_date</th><th>payment_method</th><th>coupon_code</th></tr></thead><tbody><tr><td>o1006</td><td>2025-11-30T15:30:00Z</td><td>c105</td><td>US</td><td>199.99</td><td>USD</td><td>CREATED</td><td>2025-11-30</td><td>CARD</td><td>WELCOME10</td></tr><tr><td>o1003</td><td>2025-11-29T09:00:00Z</td><td>c102</td><td>US</td><td>15.0</td><td>USD</td><td>CANCELLED</td><td>2025-11-29</td><td>null</td><td>null</td></tr><tr><td>o1001</td><td>2025-11-28T10:05:00Z</td><td>c100</td><td>US</td><td>120.5</td><td>USD</td><td>PAID</td><td>2025-11-28</td><td>null</td><td>null</td></tr><tr><td>o1005</td><td>2025-11-30T14:00:00Z</td><td>c104</td><td>IN</td><td>499.0</td><td>INR</td><td>PAID</td><td>2025-11-30</td><td>UPI</td><td>null</td></tr><tr><td>o1004</td><td>2025-11-29T12:30:00Z</td><td>c103</td><td>GB</td><td>75.0</td><td>GBP</td><td>CREATED</td><td>2025-11-29</td><td>null</td><td>null</td></tr><tr><td>o1002</td><td>2025-11-28T11:10:00Z</td><td>c101</td><td>IN</td><td>2500.0</td><td>INR</td><td>PAID</td><td>2025-11-28</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# Task 9: OPTIMIZE and optional ZORDER.
# These improve performance by compacting small files and clustering data.

try:
    spark.sql(f"OPTIMIZE delta.`{path}`")
    spark.sql(f"OPTIMIZE delta.`{path}` ZORDER BY (customer_id)")
    print("OPTIMIZE + ZORDER finished.")
except Exception as e:
    print("OPTIMIZE/ZORDER not supported:", e)
# Out:
# OPTIMIZE + ZORDER finished.

# %%
# Task 10: Small file problem demo.
# Creating many tiny partitions shows why OPTIMIZE is needed to compact Delta files.

small_path = path + "_smallfiles_demo"
dbutils.fs.rm(small_path, recurse=True)

rows = []
base = datetime.date(2025, 11, 1)
for i in range(50):
    rows.append({
        "order_id": f"tiny_{i}",
        "order_timestamp": f"2025-11-{(i % 30) + 1:02d} 10:00:00",
        "customer_id": f"ct_{i}",
        "country": "US",
        "amount": float(i + 1),
        "currency": "USD",
        "status": "PAID",
        "order_date": base + datetime.timedelta(days=i)
    })

tiny_df = spark.createDataFrame(rows)
tiny_df = tiny_df.withColumn("order_timestamp", col("order_timestamp").cast(TimestampType()))
tiny_df = tiny_df.withColumn("order_date", to_date(col("order_date")))

tiny_df.write.format("delta").mode("overwrite").partitionBy("order_date").save(small_path)

display(dbutils.fs.ls(small_path))

# Try compacting small files
try:
    spark.sql(f"OPTIMIZE delta.`{small_path}`")
except:
    print("OPTIMIZE not supported on this runtime.")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1764602779000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-01/</td><td>order_date=2025-11-01/</td><td>0</td><td>1764602779000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-02/</td><td>order_date=2025-11-02/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-03/</td><td>order_date=2025-11-03/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-04/</td><td>order_date=2025-11-04/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-05/</td><td>order_date=2025-11-05/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-06/</td><td>order_date=2025-11-06/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-07/</td><td>order_date=2025-11-07/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-08/</td><td>order_date=2025-11-08/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-09/</td><td>order_date=2025-11-09/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-10/</td><td>order_date=2025-11-10/</td><td>0</td><td>1764602781000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-11/</td><td>order_date=2025-11-11/</td><td>0</td><td>1764602781000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-12/</td><td>order_date=2025-11-12/</td><td>0</td><td>1764602781000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-13/</td><td>order_date=2025-11-13/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-14/</td><td>order_date=2025-11-14/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-15/</td><td>order_date=2025-11-15/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-16/</td><td>order_date=2025-11-16/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-17/</td><td>order_date=2025-11-17/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-18/</td><td>order_date=2025-11-18/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-19/</td><td>order_date=2025-11-19/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-20/</td><td>order_date=2025-11-20/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/data/shopez_new/orders_smallfiles_demo/order_date=2025-11-21/</td><td>order_date=2025-11-21/</td><td>0</td><td>1764602780000</td></tr><tr><td>dbfs:/Volumes/rithika/default/d ...
